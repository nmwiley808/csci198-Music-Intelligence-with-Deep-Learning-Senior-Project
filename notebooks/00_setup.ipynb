# %% [markdown]
# <a href="https://colab.research.google.com/github/nmwiley808/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project/blob/main/notebooks/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CSCI 198 - Google Colab Setup
# Music Intelligence with Deep Learning

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB

# %%
# !git clone https://github.com/nmwiley808/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project.git
# Out:
# Cloning into 'csci198-Music-Intelligence-with-Deep-Learning-Senior-Project'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 42 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 20.81 KiB | 20.81 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# %cd csci198-Music-Intelligence-with-Deep-Learning-Senior-Project
# !ls
# Out:
# /content/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project
# LICENSE  notebooks  README.md  requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 117.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 7.0.0
#     Uninstalling cachetools-7.0.0:
#       Successfully uninstalled cachetools-7.0.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import librosa
import numpy
import pandas
print("Basic imports OK")
# Out:
# Basic imports OK
