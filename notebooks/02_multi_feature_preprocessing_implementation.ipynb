# %% [markdown]
# <a href="https://colab.research.google.com/github/nmwiley808/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project/blob/main/notebooks/02_multi_feature_preprocessing_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 02 - Multi Feature Preprocessing Implementation
#
# ## Description
# This notebook implements unified preprocessing functions for:
#
# - Mel Spectrogram
# - Log-Mel Spectrogram
# - MFCC
#
# The pipelne is applied consistently across:
# - GTZAN
# - MTG-Jamendo
# - MangnaTagATune
#
# Objectives:
# - Standardize sampling rate and clip durration
# - Extract consistent feature dimensions
# - Verify cross-dataset shape consistency
# ---

# %%
# Mount Drive & Navigate
from google.colab import drive
import os

drive.mount('/content/drive')

base_path = "/content/drive/MyDrive/csci198"
repo_name = "csci198-Music-Intelligence-with-Deep-Learning-Senior-Project"
full_path = os.path.join(base_path, repo_name)

# %cd {full_path}
print("Current Directory:", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/csci198/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project
# Current Directory: /content/drive/MyDrive/csci198/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project

# %%
# Imports
import librosa
import librosa.display
import numpy as np
import os
import pandas as pd

# %%
# Unified Audio Configuration
SAMPLE_RATE = 22050
DURATION = 5 # Will be using 5 seconds for consistency across datasets
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

N_MELS = 128
N_MFCC = 20
