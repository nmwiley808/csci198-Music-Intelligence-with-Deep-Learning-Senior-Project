# %% [markdown]
# <a href="https://colab.research.google.com/github/nmwiley808/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project/blob/main/notebooks/01_multi-dataset_download_and_inspection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01 - Multi Dataset Download & Inspection
#
# ## Description
#
# This notebook establishes the foundational datasets for the Music Intelligence Senior Project. Three widely used benchmark music datasets obtained and inspected:
#
# 1. **GTZAN** (Kaggle) – Single-label genre classification dataset (22,050 Hz WAV files).
# 2. **FMA Small** (Kaggle) – Balanced single-label genre dataset consisting of 30-second audio clips.
# 3. **MagnaTagATune** (Kaggle) – Multi-label music tagging dataset (8,000 Hz WAV files).
#
# ---
#
# ## Objectives
#
# - Download datasets from stable and reproducible Kaggle sources.
# - Verify folder structure and dataset organization.
# - Inspect audio formats, sampling rates, and duration.
# - Identify potential corrupted or duplicate files.
# - Examine metadata and label formats.
# - Define a unified label schema to support cross-dataset experimentation.
#
# ---
#
# ## Outcome
#
# By the end of this notebook:
#
# - All datasets are locally stored within the project structure.
# - Audio characteristics across datasets are verified and documented.
# - Differences in sampling rates and label formats are clearly identified.
# - The project is prepared for Week 3 preprocessing and feature extraction.

# %%
# Mount Drive & Navigate
from google.colab import drive
import os

drive.mount('/content/drive')

base_path = "/content/drive/MyDrive/csci198"
repo_name = "csci198-Music-Intelligence-with-Deep-Learning-Senior-Project"
full_path = os.path.join(base_path, repo_name)

# %cd {full_path}
print("Current Directory:", os.getcwd())
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/csci198/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project
# Current Directory: /content/drive/MyDrive/csci198/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project

# %%
# Create Structured Data Folders
folders = [
    "data/raw/gtzan",
    "data/raw/fma",
    "data/raw/magnatagatune",
    "data/interim",
    "data/processed"
]

for folder in folders:
  os.makedirs(folder, exist_ok=True)

print("Structured data directories ready.")
# Out:
# Structured data directories ready.

# %% [markdown]
# # GTZAN
#
# ---

# %%
# Upload Kaggle API File
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d591c0b0-70ef-45f8-8d3f-592596818fda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d591c0b0-70ef-45f8-8d3f-592596818fda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Configure Kaggle
import os

os.makedirs('/root/.kaggle', exist_ok=True)
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

print("Kaggle API configured successfully.")
# Out:
# Kaggle API configured successfully.

# %%
# Verify Kaggle Works
# !kaggle datasets list -s gtzan
# Out:
# ref                                                      title                                                 size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  ---------------------------------------------  -----------  --------------------------  -------------  ---------  ---------------
# andradaolteanu/gtzan-dataset-music-genre-classification  GTZAN Dataset - Music Genre Classification      1301492495  2020-03-24 14:05:33.357000         112925        925  0.88235295
# carlthome/gtzan-genre-collection                         GTZAN Genre Collection                          1225975597  2019-10-30 07:38:06.633000           8557         76  0.8125
# lnicalo/gtzan-musicspeech-collection                     GTZAN music/speech collection                    296835448  2017-10-24 12:52:44.587000           2834         43  0.625
# ...

# %%
# Download GTZAN
# %cd data/raw/gtzan

# !kaggle datasets download -d andradaolteanu/gtzan-dataset-music-genre-classification
# !unzip -q gtzan-dataset-music-genre-classification.zip

# %cd ../../../
# Out:
# /content/drive/MyDrive/csci198/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project/data/raw/gtzan
# Dataset URL: https://www.kaggle.com/datasets/andradaolteanu/gtzan-dataset-music-genre-classification
# License(s): other
# ...
# 100% 1.21G/1.21G [00:11<00:00, 130MB/s]
# 100% 1.21G/1.21G [00:11<00:00, 117MB/s]
# /content/drive/MyDrive/csci198/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project

# %% [markdown]
# # FMA Small
#
# ---

# %%
# Upload Kaggle API File
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-38fa63ba-60c7-4d90-a876-b16f1c6596ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38fa63ba-60c7-4d90-a876-b16f1c6596ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Configure Kaggle
import os

os.makedirs('/root/.kaggle', exist_ok=True)
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

print("Kaggle API configured successfully.")
# Out:
# Kaggle API configured successfully.

# %%
# Verify Kaggle Works
# !kaggle datasets list -s FMA
# Out:
# ref                                                title                                              size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------------  -----------------------------------------  ------------  --------------------------  -------------  ---------  ---------------
# imsparsh/fma-free-music-archive-small-medium       FMA - Free Music Archive - Small & Medium   31961630661  2021-01-31 21:43:19.353000           4566         44  0.7058824
# brunosette/fma-large                               FMA Large                                  100805322702  2025-02-11 22:26:40.823000            162          2  0.75
# veronikafilippou/fmarockvshiphop                   fma-rock-vs-hiphop                               612165  2019-04-02 11:36:45.530000            249          5  0.1764706
# ...

# %%
# Download FMA
# %cd data/raw/fma

# !kaggle datasets download -d imsparsh/fma-free-music-archive-small-medium

# !unzip -q fma-free-music-archive-small-medium.zip
# Out:
# /content/drive/MyDrive/csci198/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project/data/raw/fma
# Dataset URL: https://www.kaggle.com/datasets/imsparsh/fma-free-music-archive-small-medium
# License(s): CC0-1.0
# ^C
# unzip:  cannot find or open fma-free-music-archive-small-medium.zip, fma-free-music-archive-small-medium.zip.zip or fma-free-music-archive-small-medium.zip.ZIP.

# %% [markdown]
# # MagnaTagATune
#
# ---

# %%
# Upload Kaggle API File
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-51881e17-3092-4323-b51a-7bb071b6fc25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51881e17-3092-4323-b51a-7bb071b6fc25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Configure Kaggle
import os

os.makedirs('/root/.kaggle', exist_ok=True)
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

print("Kaggle API configured successfully.")
# Out:
# Kaggle API configured successfully.

# %%
# Verify Kaggle Works
# !kaggle datasets list -s magnatagatune
# Out:
# ref                                    title                           size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------  ------------------------  ----------  --------------------------  -------------  ---------  ---------------
# yalumusic/magnatagatune                MagnaTagATune             2984882210  2025-11-20 11:01:41.223000             14          1  0.5882353
# stefanneacsu/magnatagatune-pcm8-top50  magnatagatune_pcm8_top50  5753468875  2025-01-03 19:03:42.290000             55          0  1.0

# %%
# MagnaTagATune Download
# %cd data/raw/magnatagatune

# !kaggle datasets download -d yalumusic/magnatagatune
# !unzip -o MagnaTagATune.zip

# %cd ../../../
# Out:
# /content/drive/MyDrive/csci198/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project/data/raw/magnatagatune
# Dataset URL: https://www.kaggle.com/datasets/yalumusic/magnatagatune
# License(s): Attribution-NonCommercial-ShareAlike 3.0 IGO (CC BY-NC-SA 3.0 IGO)
# ...
#  99% 2.76G/2.78G [00:22<00:00, 172MB/s]
# 100% 2.78G/2.78G [00:22<00:00, 135MB/s]
# unzip:  cannot find or open MagnaTagATune.zip, MagnaTagATune.zip.zip or MagnaTagATune.zip.ZIP.
# /content/drive/MyDrive/csci198/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project
