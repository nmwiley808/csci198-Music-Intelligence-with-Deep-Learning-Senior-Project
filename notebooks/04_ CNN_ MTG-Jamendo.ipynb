# %% [markdown]
# <a href="https://colab.research.google.com/github/nmwiley808/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project/blob/main/notebooks/04_%20CNN_%20MTG-Jamendo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04 - CNN Baseline on MTG-Jamendo
#
# ## Description
#
# This notebook trains a multi-label CNN on the MTG-Jamendo dataset
#
# Differences from GTZAN:
# - Multi-label classification
# - Sigmoid outputs
# - BCEwithLogitsLoss
# - Evaluation using Macro F1 score
#
# This establishes the CNN baseline for MTG-Jamendo
