# %% [markdown]
# <a href="https://colab.research.google.com/github/nmwiley808/csci198-Music-Intelligence-with-Deep-Learning-Senior-Project/blob/main/notebooks/01_dataset_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CSCI 198 - Week 2
# ## 01 - Dataset Download Setup
#
# This notebook prepares dataset storage and verifies enviroment before downloading full datasets.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

DATA_ROOT = "/content/drive/MyDrive/csci198-data"

folders = [
    "gtzan",
    "mtg_jamendo",
    "magnatagatune",
    "metadata"
]

for folder in folders:
    os.makedirs(os.path.join(DATA_ROOT, folder), exist_ok=True)

print("Dataset structure ready at:", DATA_ROOT)
# Out:
# Dataset structure ready at: /content/drive/MyDrive/csci198-data

# %%
# !ls /content/drive/MyDrive/csci198-data
# Out:
# gtzan  magnatagatune  metadata	mtg_jamendo

# %%
import librosa
import soundfile

print("Audio libraries ready.")
# Out:
# Audio libraries ready.
